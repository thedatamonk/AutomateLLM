# %% [markdown]
# # Introduction

# %% [markdown]
# ### Imports

# %%
from rag import AutomateRAG

# %%
rag = AutomateRAG()
# Out:
# Integrations metadata loaded successfully.

# %% [markdown]
# ### RAG pipeline 1
#
# Retrieve all examples

# %%
output = rag.automate("Post Linear issues to Slack every weekday at 9am using Cron.")
print (output)
# Out:
# Job description
# ----------------------------------------------------------------------------------------------------
# Post Linear issues to Slack every weekday at 9am using Cron.
#
#
# Tasks and Trigger:
# ----------------------------------------------------------------------------------------------------
# {
#     "job_trigger": {
#         "type": "schedule",
#         "explanation": "Trigger type is 'schedule' because job will trigger every weekday at 9 AM.",
#         "params": "Every weekday at 9 AM.",
#         "integrations": []
#     },
#     "tasks": [
#         {
#             "task_sequence_id": 1,
#             "task_desc": "Fetch all Linear issues that were updated or created since the last run.",
#             "integrations": [
#                 "linear"
#             ]
#         },
#         {
#             "task_sequence_id": 2,
#             "task_desc": "Post the fetched Linear issues to a specified Slack channel.",
#             "integrations": [
#                 "slack"
#             ]
#         }
#     ]
# }
#
#
# Identified unique integrations:
# ----------------------------------------------------------------------------------------------------
# ['slack', 'linear']
#
# 8 integration examples loaded.
#
#
# import { TriggerClient, cronTrigger } from "@trigger.dev/sdk";
# import { Linear } from "@trigger.dev/linear";
# import { Slack } from "@trigger.dev/slack";
#
# const linear = new Linear({ id: "linear", apiKey: process.env.LINEAR_API_KEY! });
# const slack = new Slack({ id: "slack" });
#
# // Define the client for trigger.dev
# const client = new TriggerClient();
#
# // Define a job that posts Linear issues to Slack every weekday at 9am
# client.defineJob({
#   id: "post-linear-issues-to-slack",
#   name: "Post Linear issues to Slack",
#   version: "1.0.0",
#   integrations: {
#     linear,
#     slack,
#   },
#   trigger: cronTrigger({
#     // Cron expression for every weekday at 9 AM
#     cron: "0 9 * * 1-5",
#   }),
#   run: async (payload, io, ctx) => {
#     // Fetch all Linear issues that were updated or created since the last run
#     const issues = await io.linear.issues("fetch-linear-issues", {
#       // Assuming a filter or pagination might be needed here
#       // This example does not specify the exact filter criteria
#     });
#
#     // Post the fetched Linear issues to a specified Slack channel
#     await io.slack.postMessage("post-linear-issues", {
#       channel: process.env.SLACK_CHANNEL_ID!,
#       text: `Here are the Linear issues updated or created since the last run:\n${issues.nodes.map(issue => issue.title).join('\n')}`,
#       // Additional formatting or information can be added here
#     });
#   },
# });

# %% [markdown]
# ### RAG pipeline 2
#
# Retrieve only relevant examples

# %%
output = rag.smart_automate("Send an email via Gmail to the user confirming that 'Account deletion was successful' when a user deletes their Slack account. All slack user accounts are stored in airtable database. So you will have to delete the appropriate user records from airtable.")
print (output)
# Out:
# Job description
# ----------------------------------------------------------------------------------------------------
# Send an email via Gmail to the user confirming that 'Account deletion was successful' when a user deletes their Slack account. All slack user accounts are stored in airtable database. So you will have to delete the appropriate user records from airtable.
#
#
# Tasks and Trigger:
# ----------------------------------------------------------------------------------------------------
# {
#     "job_trigger": {
#         "type": "event",
#         "explanation": "Trigger type is 'event' because job will listen to 'Account deletion' events from Slack.",
#         "params": "User deletes their Slack account.",
#         "integrations": [
#             "slack"
#         ]
#     },
#     "tasks": [
#         {
#             "task_sequence_id": 1,
#             "task_desc": "Delete the user's record from the Airtable database.",
#             "integrations": [
#                 "airtable"
#             ]
#         },
#         {
#             "task_sequence_id": 2,
#             "task_desc": "Send an email via Gmail to the user confirming that 'Account deletion was successful'.",
#             "integrations": [
#                 "gmail"
#             ]
#         }
#     ]
# }
#
#
# Unique integrations:
# ----------------------------------------------------------------------------------------------------
# ['airtable', 'gmail', 'slack']
#
# Finding relevant examples for API: airtable...
# Here are the selected examples for API airtable:
#
# ['update-airtable-when-stripe-account-updated.txt', 'new-airtable-record-from-typeform.txt']
#
#
# Finding relevant examples for API: gmail...
# Here are the selected examples for API gmail:
#
# ['send-email-with-gmail.txt']
#
#
# Finding relevant examples for API: slack...
# Here are the selected examples for API slack:
#
# ['github-star-to-slack.txt']
#
#
# Identified and loaded 4 integration examples.
#
#
# import { TriggerClient } from "@trigger.dev/sdk";
# import { Slack } from "@trigger.dev/slack";
# import { Airtable } from "@trigger.dev/airtable";
# import { google } from "googleapis";
# import { JWT } from "google-auth-library";
#
# // Initialize Slack integration
# const slack = new Slack({
#   id: "slack",
# });
#
# // Initialize Airtable integration
# const airtable = new Airtable({
#   id: "airtable",
#   token: process.env.AIRTABLE_TOKEN!,
# });
#
# // Configure JWT for Gmail
# const auth = new JWT({
#   email: process.env.GOOGLE_CLIENT_EMAIL,
#   key: process.env.GOOGLE_PRIVATE_KEY!.split(String.raw`\n`).join("\n"),
#   scopes: ["https://www.googleapis.com/auth/gmail.send"],
# });
# auth.subject = process.env.GOOGLE_IMPERSONATION_EMAIL;
#
# // Initialize the Gmail API
# const gmail = google.gmail({ version: "v1", auth });
#
# client.defineJob({
#   id: "slack-account-deletion",
#   name: "Handle Slack Account Deletion",
#   version: "1.0.0",
#   integrations: {
#     slack,
#     airtable,
#   },
#   trigger: slack.onEvent({
#     event: "account_deletion",
#     explanation: "Listens to account deletion events from Slack.",
#   }),
#   run: async (payload, io, ctx) => {
#     // Task 1: Delete the user's record from the Airtable database
#     const usersTable = io.airtable
#       .base("<your-base-id>")
#       .table("<your-table-name>");
#
#     // Assuming 'slackUserId' is a field in the Airtable that matches the Slack user ID
#     const records = await usersTable.getRecords("Filter records by slackUserId", {
#       filterByFormula: `{slackUserId} = "${payload.user.id}"`,
#     });
#
#     if (records.length > 0) {
#       await usersTable.deleteRecords("Delete user record", records.map(record => record.id));
#     }
#
#     // Task 2: Send an email via Gmail to the user confirming that 'Account deletion was successful'
#     const userEmail = payload.user.email; // Assuming payload contains user email
#     const emailSubject = "Account Deletion Confirmation";
#     const emailBody = "Your Slack account has been successfully deleted.";
#
#     const email = `To: ${userEmail}\r\nSubject: ${emailSubject}\r\n\r\n${emailBody}`;
#
#     await io.runTask(
#       "Send Gmail",
#       async () => {
#         await gmail.users.messages.send({
#           userId: "me",
#           requestBody: {
#             raw: Buffer.from(email).toString("base64"),
#           },
#         });
#       },
#       { name: "Send Gmail", icon: "google" }
#     );
#   },
# });
